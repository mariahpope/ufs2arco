# %%
import xarray as xr
import numpy as np
import dask.array as darray

# %%
#### STORE CONTAINER
ds = xr.open_zarr("gcs://noaa-ufs-gefsv13replay/ufs-hr1/0.25-degree/03h-freq/zarr/fv3.zarr",
                storage_options={"token": "anon"},)
ds = ds[['acond','tmp']]
ds = ds.isel(time=slice(0,24),
             grid_xt=slice(None, None, 4), 
             grid_yt=slice(None, None, 4))
ds['cftime'].load()
ds['ftime'].load()

# start building container
dds = xr.Dataset()
for key, da in ds.data_vars.items():
    print(key)

    dda = xr.DataArray(
        data=darray.zeros(
            shape=da.shape,
            chunks=da.chunks,
            dtype=da.dtype,
        ),
        dims=da.dims,
        coords=da.coords,
        attrs=da.attrs,
    )
    dds[key] = dda

dds
# Out:
# acond
# tmp
# <xarray.Dataset> Size: 906MB
# Dimensions:  (time: 24, grid_xt: 384, grid_yt: 192, pfull: 127)
# Coordinates:
#     cftime   (time) object 192B 1993-12-31 18:00:00 ... 1994-01-03 15:00:00
#     ftime    (time) timedelta64[ns] 192B -1 days +18:00:00 ... -1 days +21:00:00
#   * grid_xt  (grid_xt) float64 3kB 0.0 0.9375 1.875 2.812 ... 357.2 358.1 359.1
#   * grid_yt  (grid_yt) float64 2kB 89.82 88.89 87.95 ... -87.25 -88.18 -89.12
#   * time     (time) datetime64[ns] 192B 1993-12-31T18:00:00 ... 1994-01-03T15...
#   * pfull    (pfull) float32 508B 0.01278 0.02033 0.03177 ... 993.5 996.2 998.8
# Data variables:
#     acond    (time, grid_yt, grid_xt) float32 7MB dask.array<chunksize=(1, 192, 384), meta=np.ndarray>
#     tmp      (time, pfull, grid_yt, grid_xt) float32 899MB dask.array<chunksize=(1, 1, 192, 384), meta=np.ndarray>

# %%
ds = xr.open_zarr("gcs://noaa-ufs-gefsv13replay/ufs-hr1/0.25-degree/03h-freq/zarr/fv3.zarr",
                storage_options={"token": "anon"},)
ds = ds[['acond','tmp']]
ds = ds.isel(grid_xt=slice(None, None, 4), 
             grid_yt=slice(None, None, 4))

ds_subset = ds.isel(time=slice(0,3)).load()

#ds_subset = ds_subset.isel(grid_xt=slice(None, None, 4), 
#                            grid_yt=slice(None, None, 4))

ds_subset = ds_subset.chunk({"time":1, 
                             "pfull":127, 
                            "grid_yt":-1, 
                            "grid_xt":-1})

ds_subset['cftime'].load()
ds_subset['ftime'].load()

ds_subset
# Out:
# <xarray.Dataset> Size: 113MB
# Dimensions:  (time: 3, grid_yt: 192, grid_xt: 384, pfull: 127)
# Coordinates:
#     cftime   (time) object 24B 1993-12-31 18:00:00 ... 1994-01-01 00:00:00
#     ftime    (time) timedelta64[ns] 24B -1 days +18:00:00 ... -1 days +18:00:00
#   * grid_xt  (grid_xt) float64 3kB 0.0 0.9375 1.875 2.812 ... 357.2 358.1 359.1
#   * grid_yt  (grid_yt) float64 2kB 89.82 88.89 87.95 ... -87.25 -88.18 -89.12
#   * pfull    (pfull) float32 508B 0.01278 0.02033 0.03177 ... 993.5 996.2 998.8
#   * time     (time) datetime64[ns] 24B 1993-12-31T18:00:00 ... 1994-01-01
# Data variables:
#     acond    (time, grid_yt, grid_xt) float32 885kB dask.array<chunksize=(1, 192, 384), meta=np.ndarray>
#     tmp      (time, pfull, grid_yt, grid_xt) float32 112MB dask.array<chunksize=(1, 127, 192, 384), meta=np.ndarray>

# %%
path = "gcs://noaa-ufs-gefsv13replay/ufs-hr1/0.25-degree-subsampled/03h-freq/zarr/"

ds = xr.open_zarr(path,
                storage_options={"token": "anon"},)

ds
# Out:
# <xarray.Dataset> Size: 56TB
# Dimensions:        (time: 87020, grid_yt: 192, grid_xt: 384, pfull: 127)
# Coordinates:
#     cftime         (time) object 696kB dask.array<chunksize=(21755,), meta=np.ndarray>
#     ftime          (time) timedelta64[ns] 696kB dask.array<chunksize=(21755,), meta=np.ndarray>
#   * grid_xt        (grid_xt) float64 3kB 0.0 0.9375 1.875 ... 357.2 358.1 359.1
#   * grid_yt        (grid_yt) float64 2kB 89.82 88.89 87.95 ... -88.18 -89.12
#   * pfull          (pfull) float32 508B 0.01278 0.02033 0.03177 ... 996.2 998.8
#   * time           (time) datetime64[ns] 696kB 1993-12-31T18:00:00 ... 2023-1...
# Data variables: (12/179)
#     acond          (time, grid_yt, grid_xt) float32 26GB dask.array<chunksize=(1, 192, 384), meta=np.ndarray>
#     albdo_ave      (time, grid_yt, grid_xt) float32 26GB dask.array<chunksize=(1, 192, 384), meta=np.ndarray>
#     alnsf          (time, grid_yt, grid_xt) float32 26GB dask.array<chunksize=(1, 192, 384), meta=np.ndarray>
# ...
